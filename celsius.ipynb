# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46.4, 59, 71.6, 100.4], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1]) #Capa densa = neurona donde cada nodo tiene contacto con todos los nodos de la capa siguiente
modelo = tf.keras.Sequential([capa])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8675183ca8d1> in <cell line: 1>()
# ----> 1 capa = tf.keras.layers.Dense(units=1, input_shape=[1]) #Capa densa = neurona donde cada nodo tiene contacto con todos los nodos de la capa siguiente
#       2 modelo = tf.keras.Sequential([capa])
#
# NameError: name 'tf' is not defined

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss="mean_squared_error"
)

# %%
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
print(historial)
plt.plot(historial.history["loss"])
# Out:
# <keras.src.callbacks.History object at 0x7b06192c6680>

# %%
resultado = modelo.predict([100])
print(str(resultado))
# Out:
# 1/1 [==============================] - 0s 35ms/step
# [[211.99425]]

# %%
print(capa.get_weights())
# Out:
# [array([[1.8003577]], dtype=float32), array([31.958479], dtype=float32)]
